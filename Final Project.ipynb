# %%
# Install kaggle and dotenv libraries if needed
# !pip install kaggle
# !pip install dotenv

# Libraries for loading kaggle data and token anonimity in Github
import os
from kaggle.api.kaggle_api_extended import KaggleApi
from dotenv import load_dotenv

# Libraries for data analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# %%
# Load .env file to import personal Kaggle username and API key
load_dotenv()

# Set Kaggle credentials .env file
# Note that Kaggle credentials are obtained from your kaggle.json file
os.environ['KAGGLE_USERNAME'] = os.getenv('KAGGLE_USERNAME')
os.environ['KAGGLE_KEY'] = os.getenv('KAGGLE_KEY')

# Authenticate with Kaggle API
api = KaggleApi()
api.authenticate()

# Download and unzip dataset
api.dataset_download_files('datasetengineer/eviot-predictivemaint-dataset', path='./', unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/datasetengineer/eviot-predictivemaint-dataset

# %%
df = pd.read_csv('EV_Predictive_Maintenance_Dataset_15min.csv')
print(f'Downloaded CSV Data:')
df.head()
# Out:
# Downloaded CSV Data:
#              Timestamp       SoC       SoH  Battery_Voltage  Battery_Current  \
# 0  2020-01-01 00:00:00  0.826099  0.941338       210.163881       -22.753095
# 1  2020-01-01 00:15:00  0.064728  0.916059       364.000102       -27.701120
# 2  2020-01-01 00:30:00  0.873643  0.908020       388.855089       -36.646406
# 3  2020-01-01 00:45:00  0.853009  0.916476       370.570602       -37.609429
# 4  2020-01-01 01:00:00  0.947540  0.913206       390.011904       -14.275808
#
#    Battery_Temperature  Charge_Cycles  Motor_Temperature  Motor_Vibration  \
# 0            27.149201     149.190930          48.496049         0.369095
# 1            53.655101     171.702388          57.829492         1.449195
# 2            29.559090     191.617645          46.518363         1.859045
# 3            29.690283     111.881817          54.163681         0.381500
# 4            28.864338     163.774377          42.075978         0.433927
#
#    Motor_Torque  ...  Load_Weight  Driving_Speed  Distance_Traveled  \
# 0    113.435589  ...   741.754518     103.421162          66.232383
# 1    105.587160  ...   769.134035      46.041935           3.146238
# 2    119.610302  ...   917.262931      59.588422          79.909148
# 3    182.535625  ...   600.598736      44.222285           0.774000
# 4    173.298044  ...   613.153029      41.374684           2.872124
#
#    Idle_Time  Route_Roughness         RUL  Failure_Probability  \
# 0   0.520922         0.225970  260.503381                    0
# 1   0.844005         0.204350  212.813954                    0
# 2   0.992405         0.175125  273.394511                    0
# 3   0.007615         0.213264  229.508442                    0
# 4   0.771938         0.770257  257.302631                    1
#
#    Maintenance_Type         TTF  Component_Health_Score
# 0                 1  111.116697                0.852745
# 1                 2  179.229425                0.827616
# 2                 1  171.852663                0.876887
# 3                 0  165.221328                0.816290
# 4                 0  176.890659                0.744260
#
# [5 rows x 30 columns]

# %%
print(df.shape)

df_avg = df

# Convert from object to datetime
df_avg['Timestamp'] = pd.to_datetime(df_avg['Timestamp'])

df_avg['Timestamp'] = (df_avg['Timestamp'] - df_avg['Timestamp'].iloc[0]).dt.total_seconds() / 60
df_avg = df_avg.groupby(df.index//900).mean().reset_index(drop=True)

# print(df_avg.shape)

df_avg.head()
# df_avg.info()
# Out:
# (175393, 30)
#    Timestamp       SoC       SoH  Battery_Voltage  Battery_Current  \
# 0     6742.5  0.774050  0.890344       354.594054       -49.704360
# 1    20242.5  0.770040  0.883914       352.464748       -48.093645
# 2    33742.5  0.786443  0.879167       351.578072       -47.906614
# 3    47242.5  0.787542  0.879226       351.431010       -47.865638
# 4    60742.5  0.799291  0.882558       356.492984       -48.106922
#
#    Battery_Temperature  Charge_Cycles  Motor_Temperature  Motor_Vibration  \
# 0            33.374391     229.444263          56.122882         0.519701
# 1            33.217258     224.116949          56.334298         0.540546
# 2            33.122914     218.863375          55.362109         0.542792
# 3            33.229750     212.521786          55.809465         0.510660
# 4            33.425594     223.828395          56.397721         0.531702
#
#    Motor_Torque  ...  Load_Weight  Driving_Speed  Distance_Traveled  \
# 0    183.044791  ...   905.333047      56.972716          15.519929
# 1    179.720302  ...   870.976512      57.402344          15.572584
# 2    182.891656  ...   909.818770      58.067192          13.969777
# 3    184.629084  ...   907.248934      58.514026          16.956550
# 4    178.173336  ...   890.408257      57.544187          15.922932
#
#    Idle_Time  Route_Roughness         RUL  Failure_Probability  \
# 0   1.441046         0.303646  216.824120             0.097778
# 1   1.543671         0.299372  215.461552             0.108889
# 2   1.538913         0.297116  217.145524             0.086667
# 3   1.413054         0.277158  212.980267             0.096667
# 4   1.619683         0.300025  214.334406             0.090000
#
#    Maintenance_Type         TTF  Component_Health_Score
# 0          0.476667  132.324095                0.758798
# 1          0.518889  128.506956                0.744789
# 2          0.530000  127.304572                0.743041
# 3          0.484444  132.981833                0.735700
# 4          0.503333  127.610135                0.753032
#
# [5 rows x 30 columns]

# %%
# Plot of daily averaged SoH and SoC data
plt.style.use('seaborn-v0_8-whitegrid')
fig1, ax = plt.subplots(figsize=(12,8))

ax.plot(df_avg['Timestamp'], df_avg['SoH'], label='SoH')
ax.plot(df_avg['Timestamp'], df_avg['SoC'], label='SoC')
ax.set_title('Time Averaged Data')
ax.set_ylabel('(%)')
ax.set_xlabel('Time (min)')
plt.legend()
plt.show()

# %%
# Plot of raw SoH data (every 15 mins)
plt.style.use('seaborn-v0_8-whitegrid')
fig1, ax = plt.subplots(figsize=(12,8))

ax.plot(df['Timestamp'][:2000], df['SoH'][:2000])
ax.set_title('Raw Data SoH')
ax.set_ylabel('SoH (%)')
ax.set_xlabel('Time (min)')
# Out:
# Text(0.5, 0, 'Time (min)')

# %%
df_avg_sorted_SoH = df.sort_values(by='SoH', ascending=False).reset_index(drop=True)
df_avg_sorted_SoH.head()
# Out:
#    Timestamp       SoC       SoH  Battery_Voltage  Battery_Current  \
# 0  1662375.0  0.900357  0.999999       372.276846       -19.630855
# 1  1248300.0  0.961530  0.999999       369.285086       -16.517292
# 2  1380540.0  0.961595  0.999998       399.258172       -19.001068
# 3   484425.0  0.951600  0.999997       389.851812       -20.127079
# 4   459975.0  0.175747  0.999996       370.680202       -14.494217
#
#    Battery_Temperature  Charge_Cycles  Motor_Temperature  Motor_Vibration  \
# 0            27.870126     133.298885          93.833881         0.441962
# 1            52.367364     581.611439          46.360209         0.342762
# 2            27.827353     131.745188          41.498904         0.268298
# 3            31.268834     195.233772          59.769448         0.419561
# 4            30.675178     194.466230          53.056707         0.267190
#
#    Motor_Torque  ...  Load_Weight  Driving_Speed  Distance_Traveled  \
# 0    129.559271  ...  1713.128829      47.320939           1.657825
# 1    199.303112  ...   956.845277     107.074960           1.661694
# 2    109.160593  ...   588.571920      41.414066           7.080552
# 3    120.210632  ...   618.058306      55.941113           1.612461
# 4    100.852068  ...   788.354819      45.300316           9.127234
#
#    Idle_Time  Route_Roughness         RUL  Failure_Probability  \
# 0   0.142262         0.205679  211.209243                    0
# 1   0.378785         0.207402  257.970495                    1
# 2   0.515971         0.883484   18.267540                    1
# 3   9.288028         0.729876  284.510090                    1
# 4   8.393918         0.245725   40.583509                    0
#
#    Maintenance_Type         TTF  Component_Health_Score
# 0                 0    2.367035                0.742448
# 1                 0  112.174238                0.897206
# 2                 0  165.271743                0.969153
# 3                 0  163.737001                0.972856
# 4                 2  105.251974                0.783286
#
# [5 rows x 30 columns]

# %%
plt.style.use('seaborn-v0_8-whitegrid')
fig, ax = plt.subplots(figsize=(12, 8))

ax.plot(df_avg_sorted_SoH.index, df_avg_sorted_SoH['SoH'], label='SoH')

ax.set_title('Time Averaged Data')
ax.set_xlabel('Index')
ax.set_ylabel('SoH (%)')

ax.legend()
plt.show()
